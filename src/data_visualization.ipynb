# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ○ Visualize data distributions using histograms, box plots, and scatter plots.

# %%
#implelmenting histogram for Phase 1 csv
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")
df=pd.DataFrame(data)
numeric_columns=df.select_dtypes(include=['int','float']).hist(bins=10,figsize=(20,10))
plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\1128011207.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")

# %%
#implelmenting histogram for IQR cleaned data
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")
df=pd.DataFrame(data)
numeric_columns=df.select_dtypes(include=['int','float']).hist(bins=10,figsize=(20,10))
plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\3009909137.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")

# %%
#implelmenting histogram for Z score df 
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Z_score_df.csv")
df=pd.DataFrame(data)
numeric_columns=df.select_dtypes(include=['int','float']).hist(bins=10,figsize=(20,10))
plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\1655114409.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Z_score_df.csv")

# %%
#Boxplot Visualization for  Phase1 csv
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")
df=pd.DataFrame(data)
numeric_col=df.select_dtypes(include=['int','float']).columns
plt.figure(figsize=(20, len(numeric_col) * 3))
for i, col in enumerate(numeric_col, 1):
    plt.subplot(len(numeric_col), 1, i)
    sns.boxplot(x=df[col], color='salmon')
    plt.title(f'Box Plot of {col}')
    plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\4235096746.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")

# %%
#Boxplot Visualization for  IQR  
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")
df=pd.DataFrame(data).drop(columns="Unnamed: 0")
numeric_col=df.select_dtypes(include=['int','float']).columns
plt.figure(figsize=(20, len(numeric_col) * 3))
for i, col in enumerate(numeric_col, 1):
    plt.subplot(len(numeric_col), 1, i)
    sns.boxplot(x=df[col], color='salmon')
    plt.title(f'Box Plot of {col}')
    plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\1903214171.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")

# %%
#Boxplot Visualization
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Z_score_df.csv")
df=pd.DataFrame(data).drop(columns="Unnamed: 0")
numeric_col=df.select_dtypes(include=['int','float']).columns
plt.figure(figsize=(20, len(numeric_col) * 3))
for i, col in enumerate(numeric_col, 1):
    plt.subplot(len(numeric_col), 1, i)
    sns.boxplot(x=df[col], color='salmon')
    plt.title(f'Box Plot of {col}')
    plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\4220930363.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Z_score_df.csv")

# %%
# Correlation for the  Phase 1 csv
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")
df=pd.DataFrame(data)
df=df.select_dtypes(include=['int','float'])
correlation_matrix = df.corr()


plt.figure(figsize=(18, 14))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=18)
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\509775978.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")

# %%
# Correlation for the  IQR Methode
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")
df=pd.DataFrame(data).drop(columns="Unnamed: 0")
df=df.select_dtypes(include=['int','float'])
correlation_matrix = df.corr()


plt.figure(figsize=(18, 14))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=18)
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_31312\3885493836.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")

# %%
# Correlation for the  ZScore csv
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Z_score_df.csv")
df=pd.DataFrame(data)
df=df.select_dtypes(include=['int','float'])
correlation_matrix = df.corr()


plt.figure(figsize=(18, 14))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=18)
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_23316\2403168277.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Z_score_df.csv")
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
