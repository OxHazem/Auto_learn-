# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ○ Visualize data distributions using histograms, box plots, and scatter plots.

# %%
#implelmenting histogram 
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")
df=pd.DataFrame(data)
numeric_columns=df.select_dtypes(include=['int','float']).hist(bins=10,figsize=(20,10))
plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_31312\3920759097.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12652 entries, 0 to 12651
# Data columns (total 32 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              12652 non-null  int64
#  1   syn_error_rate                          12652 non-null  float64
#  2   connection_time                         12652 non-null  int64
#  3   destination_same_source_port_rate       12652 non-null  float64
#  4   destination_different_server_rate       12652 non-null  float64
#  5   connection_status                       12652 non-null  object
#  6   connection_count                        12652 non-null  int64
#  7   destination_server_different_host_rate  12652 non-null  float64
#  8   suspicious_activity                     12652 non-null  int64
#  9   protocol                                12652 non-null  object
#  10  server_different_host_rate              12652 non-null  float64
#  11  destination_server_syn_error_rate       12652 non-null  float64
#  12  destination_host_server_count           12652 non-null  int64
#  13  destination_same_server_rate            12652 non-null  float64
#  14  fragment_errors                         12652 non-null  int64
#  15  compromised_count                       12652 non-null  int64
#  16  source_bytes                            12652 non-null  int64
#  17  service_type                            12652 non-null  object
#  18  destination_syn_error_rate              12652 non-null  float64
#  19  same_server_rate                        12652 non-null  float64
#  20  reset_error_rate                        12652 non-null  float64
#  21  server_request_count                    12652 non-null  int64
#  22  destination_server_reset_error_rate     12652 non-null  float64
#  23  server_reset_error_rate                 12652 non-null  float64
#  24  server_syn_error_rate                   12652 non-null  float64
#  25  destination_bytes                       12652 non-null  int64
#  26  guest_login                             12652 non-null  int64
#  27  authentication_status                   12652 non-null  int64
#  28  destination_host_count                  12652 non-null  int64
#  29  destination_reset_error_rate            12652 non-null  float64
#  30  different_server_rate                   12652 non-null  float64
#  31  class                                   12652 non-null  object
# dtypes: float64(15), int64(13), object(4)
# memory usage: 3.1+ MB

# %%
#Boxplot Visualization
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")
df=pd.DataFrame(data)
numeric_col=df.select_dtypes(include=['int','float']).columns
plt.figure(figsize=(20, len(numeric_col) * 3))
for i, col in enumerate(numeric_col, 1):
    plt.subplot(len(numeric_col), 1, i)
    sns.boxplot(x=df[col], color='salmon')
    plt.title(f'Box Plot of {col}')
    plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_31312\699698148.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")

# %%
#Boxplot Visualization
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")
df=pd.DataFrame(data)
numeric_col=df.select_dtypes(include=['int','float']).columns
plt.figure(figsize=(20, len(numeric_col) * 3))
for i, col in enumerate(numeric_col, 1):
    plt.subplot(len(numeric_col), 1, i)
    sns.boxplot(x=df[col], color='salmon')
    plt.title(f'Box Plot of {col}')
    plt.tight_layout()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_31312\4232756916.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\Project_Phase1.csv")

# %%
data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")
df=pd.DataFrame(data)
df=df.select_dtypes(include=['int','float'])
correlation_matrix = df.corr()


plt.figure(figsize=(18, 14))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=18)
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Omar\AppData\Local\Temp\ipykernel_31312\3885493836.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data=pd.read_csv("D:\DownLoad\projects\Auto_learn\data\cleaned_from_outliers_df.csv")
